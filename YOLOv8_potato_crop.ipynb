# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Apr 23 13:31:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.85 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
#!unzip '/content/drive/MyDrive/Classes/YOLOv8/data.zip' -d '/content/drive/MyDrive/Classes/YOLOv8/123'

# %%
# %cd /content/drive/MyDrive/Classes/YOLOv8
# Out:
# /content/drive/MyDrive/Classes/YOLOv8

# %%
# !ls
# Out:
# 123  data.yaml	data.zip  runs	YOLOv8_potato_crop.ipynb  yolov8s.pt

# %%
# %cd /content/drive/MyDrive/Classes/YOLOv8

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=750 plots=True
# Out:
# /content/drive/MyDrive/Classes/YOLOv8
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# from ultralytics import YOLO

# model= YOLO("yolov8s.pt")
# model.train(data="data.yaml", epochs=25)

# %%
# !ls runs/detect/train/
# Out:
# args.yaml  weights

# %%
Image(filename='runs/detect/train11/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train11/results.png', width=600)

# %%
Image(filename='runs/detect/train11/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train11/weights/best.pt data=data.yaml
# Out:
# 2023-04-11 18:44:04.994999: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Classes/YOLOv8/123/data/val/labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:07<00:00,  1.78s/it]
#                    all         60       1135      0.396      0.405      0.335      0.121
#                healthy         60        401       0.39      0.397      0.325      0.112
#               stressed         60        734      0.403      0.414      0.346       0.13
# Speed: 8.0ms pre-process, 25.6ms inference, 0.0ms loss, 10.8ms post-process per image

# %%
# !yolo task=detect mode=predict model=runs/detect/train11/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Classes/YOLOv8/123/data/test/images save=True
# Out:
# 2023-04-11 18:45:44.281510: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/60 /content/drive/MyDrive/Classes/YOLOv8/123/data/test/images/image1501.jpg: 768x768 1 healthy, 1 stressed, 20.0ms
# image 2/60 /content/drive/MyDrive/Classes/YOLOv8/123/data/test/images/image1502.jpg: 768x768 3 healthys, 1 stressed, 20.1ms
# image 3/60 /content/drive/MyDrive/Classes/YOLOv8/123/data/test/images/image1503.jpg: 768x768 2 healthys, 20.1ms
# image 4/60 /content/drive/MyDrive/Classes/YOLOv8/123/data/test/images/image1504.jpg: 768x768 1 healthy, 2 stresseds, 20.1ms
# image 5/60 /content/drive/MyDrive/Classes/YOLOv8/123/data/test/images/image1505.jpg: 768x768 2 healthys, 3 stresseds, 20.1ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/Classes/YOLOv8/runs/detect/predict/*.jpg')[:6]:
      display(Image(filename=image_path, width=600))
      print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
